# %%
# %run ./CoreFunctions.ipynb

# %%
playsound(444,444)

# %%
Q_value = 47438

# %%
distance_to_points = 0.227  # determins how many new points are included per iteration
                            # higher value results in fewer iterations but more points will be computed
                            # if the value is too low, some points may be missed. Not good
                            # if the value is too high, too many points will be computed
        
        
        
Grid_size = 74               # the grid of Grid_size ^2 points is considered

# %%
N_iterations = 39 
#N_cities = len(PolPopulation)
N_cities = 4 #number of city sizes

# %%
# kI  does not! affect the ratio I_p/I_u!
kI = 0.00001

# %%
# Polush population
#Pol_Pop = pd.read_csv("beta_30_Pl_AA.csv")
#PolPopulation = np.array(Pol_Pop["SourcePopulation"])
#PolPopulation = np.sort(PolPopulation)

# %%
    # initialize cities array. The distribution is given manually

    def initialize_cities_array():
        
        # zeroth column is city size y, first is beta(y), second is pi_p(y), third  pi_U(y)
        zeta      = np.zeros((N_cities, 4))
        zeta[0,0] = 1000
        zeta[1,0] = 25369
        zeta[2,0] = 110521
        zeta[3,0] = 787445
        
        zeta[0,1] = 0.09
        zeta[1,1] = 0.05
        zeta[2,1] = 0.85
        zeta[3,1] = 0.01
        
        zeta[:,2] = 0.99 #placeholder
        zeta[:,3] = 0.99  #placeholder
    
    
        return zeta

# %%
# for Poland all city sizes are unique
if False:   
    def initialize_cities_array():
        
        # zeroth column is city size y, first is beta(y), second is pi_p(y), third  pi_U(y)
        zeta      = np.zeros((N_cities, 4))
        zeta[:,0] = PolPopulation
     
        
        zeta[:,1] = 1/N_cities
        
        zeta[:,2] = 0.99 #placeholder
        zeta[:,3] = 0.99  #placeholder
    
    
        return zeta

# %%
if Q_value > maxQ_value() - 0.1:
    raise ValueError("Q_value is too high!")

# %%
def getPointsCloseToBoundary(df, DF_boundary, distance_to_points ):
    Points_close_to_the_boundary = []

    for i in range(df.shape[0]):   # add points close to the old boundary
        ai = df["a"][i]
        bi = df["b"][i]
        Distance = 1
        for j in range(DF_boundary.shape[0]):
            aj = DF_boundary["a"][j]
            bj = DF_boundary["b"][j]
            Distance = ( (ai - aj) **2 + (bi - bj) **2  )**(0.5)
            if Distance < distance_to_points:
                Points_close_to_the_boundary.append(i)
                break

    Returndf = df.iloc[Points_close_to_the_boundary] 
    Returndf = Returndf.reset_index(drop=True) # reset indices
    
    return Returndf

def getBoundary(df):

    Indices_of_boundary_points = []

    for i in range(df.shape[0]):
        ai = df["a"][i]
        bi = df["b"][i]

        for j in range(i+1): 
            aj = df["a"][j]
            bj = df["b"][j]
            GraphDistance = (abs(ai-aj) + abs(bi-bj))/ Delta
            if GraphDistance > 0.5 and GraphDistance < 1.5:
                #print("pair")
                if abs(Signs[i]- Signs[j]) > 0.5:
                    Indices_of_boundary_points.extend([i,j])
                    
    Indices_of_boundary_points =  list(set(Indices_of_boundary_points))
    DF_boundary = df.iloc[Indices_of_boundary_points]
    Signs_boundary = Signs[Indices_of_boundary_points]
    DF_boundary = DF_boundary.reset_index(drop=True)
                    
    return DF_boundary

# %%
iteration_number = 0

Boundary_is_invariant = False

while iteration_number < 81 and not Boundary_is_invariant:
    
    iteration_number = iteration_number +1
    print( "Iteration number " + str(iteration_number) + " has began...")
    aas = np.linspace(start=-0.85, stop=2.87, num=Grid_size) 
    bbs = np.linspace(start=-1.75, stop= 1.67, num=Grid_size)
    if iteration_number == 1: 
        aas = np.linspace(start=0.5, stop=1.5, num=10) 
        bbs = np.linspace(start=0.5 - 1, stop=1.5 - 1, num=10)
    Delta = (np.max(aas) - np.min(aas))/(np.shape(aas)[0] - 1)
    
    # get cartesian product of aas and bbs
    df = pd.MultiIndex.from_product([aas, bbs], names = ["a", "b"])
    df = pd.DataFrame(index = df).reset_index()
    zeros = np.zeros(( df.shape[0],1))
    df["LogIpOverIu"] = zeros  
    df = df.sample(frac=1).reset_index(drop=True)  #shuffle rows
    
    if iteration_number == 2:
        df = getPointsCloseToBoundary(df, DF_boundary, 1.2*distance_to_points)
    if iteration_number > 2.2:
        df = getPointsCloseToBoundary(df, DF_boundary, distance_to_points)
        


        
    
    plt.scatter(df["a"], df["b"], s=1)
    plt.xlabel("a")
    plt.ylabel("b")
    plt.title('df points')
    plt.show()
    
    
    
    startTime = time.time()
    for i in range(df.shape[0]):
        
        ai = df["a"][i]
        bi = df["b"][i]
        
        Index_in_Computed_points = -2  # remains negative if this has not been computed
        if iteration_number > 2.2:
            
            for j in range(Computed_points.shape[0]):
                aj = Computed_points["a"][j]
                bj = Computed_points["b"][j]

                if abs(ai - aj) + abs( bi - bj) < 0.0001:
                    Index_in_Computed_points = j
                    break

        if Index_in_Computed_points > -0.5:
            df["LogIpOverIu"][i] = Computed_points["LogIpOverIu"][Index_in_Computed_points]
        elif abs(Index_in_Computed_points +2) < 0.001:
            ick = Compute_Is(df["a"][i], df["b"][i], Q_value)
            df["LogIpOverIu"][i] = math.log(ick[0]) - math.log(ick[1])
        else:
            raise ValueError('Sth bad happened with Index_in_Computed_points')

        if  i%53 == 6:
            print("ETA for LogIpOverIu computation in this iteration = " +
                  str( (df.shape[0] - i - 1) *(time.time() - startTime)/(i+1) ) + " seconds")
            
    print("Total time for LogIpOverIu computation in this iteration = "  + str(time.time() - startTime) )      
    if iteration_number == 2:
        Computed_points = df.copy()
        
    if iteration_number > 2:
        Computed_points = pd.concat([Computed_points,df]).drop_duplicates().reset_index(drop=True)
        
    Signs = np.zeros(np.shape(df["LogIpOverIu"]))
    for i in range(len(Signs)):
        if df["LogIpOverIu"][i] > 0:
            Signs[i] = 1
        elif df["LogIpOverIu"][i] < 0:
            Signs[i] = -1
    
    plt.scatter(df["a"], df["b"], c=Signs, s=1)
    plt.ylabel('b')
    plt.xlabel('a')
    plt.title("df dataframe")

    plt.show()
    if iteration_number > 1.2:
        DF_boundary_old = DF_boundary.copy()
    
    DF_boundary = getBoundary(df)
    Signs_boundary = np.zeros(np.shape(DF_boundary["LogIpOverIu"]))
    for i in range(len(Signs_boundary)):
        if DF_boundary["LogIpOverIu"][i] > 0:
            Signs_boundary[i] = 1
        elif DF_boundary["LogIpOverIu"][i] < 0:
            Signs_boundary[i] = -1
    
    if iteration_number > 3.2:
        if DF_boundary.shape[0] == DF_boundary_old.shape[0]:
            Boundary_is_invariant = True
    
    
    plt.scatter(DF_boundary["a"][Signs_boundary > 0], DF_boundary["b"][Signs_boundary > 0], c = "red", s=1)
    plt.scatter(DF_boundary["a"][Signs_boundary < 0], DF_boundary["b"][Signs_boundary < 0], c = "blue", s=1)
    plt.ylabel('b')
    plt.xlabel('a')
    plt.show()
# Out:
# Iteration number 1 has began...
# ETA for LogIpOverIu computation in this iteration = 67.0606677532196 seconds
# ETA for LogIpOverIu computation in this iteration = 37.83297198159354 seconds
# ETA for LogIpOverIu computation in this iteration = 22.054631359436932 seconds
# ETA for LogIpOverIu computation in this iteration = 10.191133125408276 seconds
# ETA for LogIpOverIu computation in this iteration = 1.1079619004554355 seconds
# Total time for LogIpOverIu computation in this iteration = 36.60326838493347
# Iteration number 2 has began...
# ETA for LogIpOverIu computation in this iteration = 73.78750858306884 seconds
# ETA for LogIpOverIu computation in this iteration = 82.58241891860962 seconds
# ETA for LogIpOverIu computation in this iteration = 68.7040632238575 seconds
# ETA for LogIpOverIu computation in this iteration = 60.484872534468366 seconds
# ETA for LogIpOverIu computation in this iteration = 55.96072542790285 seconds
# ETA for LogIpOverIu computation in this iteration = 53.40003379185995 seconds
# ETA for LogIpOverIu computation in this iteration = 49.12189592848291 seconds
# ETA for LogIpOverIu computation in this iteration = 44.72308294169874 seconds
# ETA for LogIpOverIu computation in this iteration = 40.79208234504417 seconds
# ETA for LogIpOverIu computation in this iteration = 38.232360273037315 seconds
# ETA for LogIpOverIu computation in this iteration = 34.658211108471484 seconds
# ETA for LogIpOverIu computation in this iteration = 30.721366082051002 seconds
# ETA for LogIpOverIu computation in this iteration = 27.246604301751297 seconds
# ETA for LogIpOverIu computation in this iteration = 23.138927597748605 seconds
# ETA for LogIpOverIu computation in this iteration = 19.84631063449638 seconds
# ETA for LogIpOverIu computation in this iteration = 16.2309951877594 seconds
# ETA for LogIpOverIu computation in this iteration = 12.256517518940944 seconds
# ETA for LogIpOverIu computation in this iteration = 8.555952862055614 seconds
# ETA for LogIpOverIu computation in this iteration = 4.815641878328346 seconds
# ETA for LogIpOverIu computation in this iteration = 1.0005600625033833 seconds
# Total time for LogIpOverIu computation in this iteration = 75.0947003364563
# Iteration number 3 has began...
# ETA for LogIpOverIu computation in this iteration = 1.489670181274414 seconds
# ETA for LogIpOverIu computation in this iteration = 11.254431094442095 seconds
# ETA for LogIpOverIu computation in this iteration = 10.015256881713867 seconds
# ETA for LogIpOverIu computation in this iteration = 10.219154953956604 seconds
# ETA for LogIpOverIu computation in this iteration = 8.35680002035554 seconds
# ETA for LogIpOverIu computation in this iteration = 7.063023334741592 seconds
# ETA for LogIpOverIu computation in this iteration = 7.1612966510799385 seconds
# ETA for LogIpOverIu computation in this iteration = 6.941272574734975 seconds
# ETA for LogIpOverIu computation in this iteration = 6.617083890097482 seconds
# ETA for LogIpOverIu computation in this iteration = 6.6877137433807805 seconds
# ETA for LogIpOverIu computation in this iteration = 6.2367798500872675 seconds
# ETA for LogIpOverIu computation in this iteration = 5.46536247397578 seconds
# ETA for LogIpOverIu computation in this iteration = 4.9342728119303745 seconds
# ETA for LogIpOverIu computation in this iteration = 4.511044974389829 seconds
# ETA for LogIpOverIu computation in this iteration = 3.7722757846937265 seconds
# ETA for LogIpOverIu computation in this iteration = 3.1498673023496355 seconds
# ETA for LogIpOverIu computation in this iteration = 2.6185574237526903 seconds
# ETA for LogIpOverIu computation in this iteration = 1.9583447142080828 seconds
# ETA for LogIpOverIu computation in this iteration = 1.3896247936603847 seconds
# ETA for LogIpOverIu computation in this iteration = 0.603029517027048 seconds
# Total time for LogIpOverIu computation in this iteration = 16.189650774002075
# Iteration number 4 has began...
# ETA for LogIpOverIu computation in this iteration = 29.898271751403808 seconds
# ETA for LogIpOverIu computation in this iteration = 18.983156144618988 seconds
# ETA for LogIpOverIu computation in this iteration = 24.182492611454983 seconds
# ETA for LogIpOverIu computation in this iteration = 27.084943674706125 seconds
# ETA for LogIpOverIu computation in this iteration = 22.99543112332059 seconds
# ETA for LogIpOverIu computation in this iteration = 21.20388142466545 seconds
# ETA for LogIpOverIu computation in this iteration = 22.126741902811546 seconds
# ETA for LogIpOverIu computation in this iteration = 20.00267683741558 seconds
# ETA for LogIpOverIu computation in this iteration = 20.468147991826296 seconds
# ETA for LogIpOverIu computation in this iteration = 17.53739362842632 seconds
# ETA for LogIpOverIu computation in this iteration = 16.537696988531884 seconds
# ETA for LogIpOverIu computation in this iteration = 14.54107843813046 seconds
# ETA for LogIpOverIu computation in this iteration = 12.831870355640017 seconds
# ETA for LogIpOverIu computation in this iteration = 11.306043818593025 seconds
# ETA for LogIpOverIu computation in this iteration = 10.354678676033604 seconds
# ETA for LogIpOverIu computation in this iteration = 9.969825447627477 seconds
# ETA for LogIpOverIu computation in this iteration = 9.274690989834374 seconds
# ETA for LogIpOverIu computation in this iteration = 7.83508401928526 seconds
# ETA for LogIpOverIu computation in this iteration = 7.099652115086667 seconds
# ETA for LogIpOverIu computation in this iteration = 5.74590172001679 seconds
# ETA for LogIpOverIu computation in this iteration = 4.673867558920255 seconds
# ETA for LogIpOverIu computation in this iteration = 3.477403952450049 seconds
# ETA for LogIpOverIu computation in this iteration = 2.2046678733452425 seconds
# ETA for LogIpOverIu computation in this iteration = 0.9341603713982114 seconds
# Total time for LogIpOverIu computation in this iteration = 29.871902465820312
# Iteration number 5 has began...
# ETA for LogIpOverIu computation in this iteration = 3.1653701782226564 seconds
# ETA for LogIpOverIu computation in this iteration = 11.99462618146624 seconds
# ETA for LogIpOverIu computation in this iteration = 35.3651258431229 seconds
# ETA for LogIpOverIu computation in this iteration = 26.91949331116032 seconds
# ETA for LogIpOverIu computation in this iteration = 27.775279394130116 seconds
# ETA for LogIpOverIu computation in this iteration = 33.358534932136536 seconds
# ETA for LogIpOverIu computation in this iteration = 30.851528361127095 seconds
# ETA for LogIpOverIu computation in this iteration = 34.08690984421466 seconds
# ETA for LogIpOverIu computation in this iteration = 33.66019855479084 seconds
# ETA for LogIpOverIu computation in this iteration = 30.28197498366518 seconds
# ETA for LogIpOverIu computation in this iteration = 32.981169891357425 seconds
# ETA for LogIpOverIu computation in this iteration = 29.932248222735502 seconds
# ETA for LogIpOverIu computation in this iteration = 27.783944808715603 seconds
# ETA for LogIpOverIu computation in this iteration = 26.041323912771123 seconds
# ETA for LogIpOverIu computation in this iteration = 22.66155195965315 seconds
# ETA for LogIpOverIu computation in this iteration = 22.47434107712337 seconds
# ETA for LogIpOverIu computation in this iteration = 20.420125042145756 seconds
# ETA for LogIpOverIu computation in this iteration = 19.89582008966292 seconds
# ETA for LogIpOverIu computation in this iteration = 17.470656019406558 seconds
# ETA for LogIpOverIu computation in this iteration = 15.565672175377204 seconds
# ETA for LogIpOverIu computation in this iteration = 13.933947651360624 seconds
# ETA for LogIpOverIu computation in this iteration = 12.150202190778295 seconds
# ETA for LogIpOverIu computation in this iteration = 9.929459568105798 seconds
# ETA for LogIpOverIu computation in this iteration = 8.10879763458552 seconds
# ETA for LogIpOverIu computation in this iteration = 6.457297486933601 seconds
# ETA for LogIpOverIu computation in this iteration = 4.571641266345978 seconds
# ETA for LogIpOverIu computation in this iteration = 2.8970047964978574 seconds
# ETA for LogIpOverIu computation in this iteration = 1.2376463691266582 seconds
# Total time for LogIpOverIu computation in this iteration = 45.654824018478394
# Iteration number 6 has began...
# ETA for LogIpOverIu computation in this iteration = 4.199997901916504 seconds
# ETA for LogIpOverIu computation in this iteration = 65.52660423517227 seconds
# ETA for LogIpOverIu computation in this iteration = 60.03054495418773 seconds
# ETA for LogIpOverIu computation in this iteration = 72.54056109931018 seconds
# ETA for LogIpOverIu computation in this iteration = 55.7732897689662 seconds
# ETA for LogIpOverIu computation in this iteration = 48.88298001885414 seconds
# ETA for LogIpOverIu computation in this iteration = 43.99477477173705 seconds
# ETA for LogIpOverIu computation in this iteration = 41.9488758265254 seconds
# ETA for LogIpOverIu computation in this iteration = 40.077491230434845 seconds
# ETA for LogIpOverIu computation in this iteration = 43.9313826336051 seconds
# ETA for LogIpOverIu computation in this iteration = 41.55397313706418 seconds
# ETA for LogIpOverIu computation in this iteration = 38.09748458030612 seconds
# ETA for LogIpOverIu computation in this iteration = 41.71733309450523 seconds
# ETA for LogIpOverIu computation in this iteration = 40.20799691975117 seconds
# ETA for LogIpOverIu computation in this iteration = 37.01649272113765 seconds
# ETA for LogIpOverIu computation in this iteration = 34.781281805038454 seconds
# ETA for LogIpOverIu computation in this iteration = 31.80224927053375 seconds
# ETA for LogIpOverIu computation in this iteration = 28.77417726950212 seconds
# ETA for LogIpOverIu computation in this iteration = 26.08841170217655 seconds
# ETA for LogIpOverIu computation in this iteration = 25.158111754046306 seconds
# ETA for LogIpOverIu computation in this iteration = 22.107861595769084 seconds
# ETA for LogIpOverIu computation in this iteration = 20.490235886612876 seconds
# ETA for LogIpOverIu computation in this iteration = 19.395458378203926 seconds
# ETA for LogIpOverIu computation in this iteration = 17.317512761341053 seconds
# ETA for LogIpOverIu computation in this iteration = 15.957197598537809 seconds
# ETA for LogIpOverIu computation in this iteration = 14.348902071344442 seconds
# ETA for LogIpOverIu computation in this iteration = 12.241673213332447 seconds
# ETA for LogIpOverIu computation in this iteration = 10.380312657584778 seconds
# ETA for LogIpOverIu computation in this iteration = 8.043275780229612 seconds
# ETA for LogIpOverIu computation in this iteration = 5.8359030559659 seconds
# ETA for LogIpOverIu computation in this iteration = 3.7195394639488604 seconds
# ETA for LogIpOverIu computation in this iteration = 1.5348153529392976 seconds
# Total time for LogIpOverIu computation in this iteration = 66.26280784606934
# Iteration number 7 has began...
# ETA for LogIpOverIu computation in this iteration = 3.5645754814147947 seconds
# ETA for LogIpOverIu computation in this iteration = 39.077274799346924 seconds
# ETA for LogIpOverIu computation in this iteration = 46.113206882102816 seconds
# ETA for LogIpOverIu computation in this iteration = 49.52458910039953 seconds
# ETA for LogIpOverIu computation in this iteration = 43.002952329891244 seconds
# ETA for LogIpOverIu computation in this iteration = 46.50602397123973 seconds
# ETA for LogIpOverIu computation in this iteration = 53.8865662954904 seconds
# ETA for LogIpOverIu computation in this iteration = 55.64345262136804 seconds
# ETA for LogIpOverIu computation in this iteration = 54.36791103857535 seconds
# ETA for LogIpOverIu computation in this iteration = 54.595001966323494 seconds
# ETA for LogIpOverIu computation in this iteration = 49.48760253013449 seconds
# ETA for LogIpOverIu computation in this iteration = 45.623106027758396 seconds
# ETA for LogIpOverIu computation in this iteration = 42.96371534286445 seconds
# ETA for LogIpOverIu computation in this iteration = 46.876103879589785 seconds
# ETA for LogIpOverIu computation in this iteration = 43.4705428377204 seconds
# ETA for LogIpOverIu computation in this iteration = 40.51672529561179 seconds
# ETA for LogIpOverIu computation in this iteration = 40.23034658892225 seconds
# ETA for LogIpOverIu computation in this iteration = 38.20166186551855 seconds
# ETA for LogIpOverIu computation in this iteration = 38.44782299642631 seconds
# ETA for LogIpOverIu computation in this iteration = 39.69005852047674 seconds
# ETA for LogIpOverIu computation in this iteration = 37.102137797365906 seconds
# ETA for LogIpOverIu computation in this iteration = 33.666101882203684 seconds
# ETA for LogIpOverIu computation in this iteration = 30.45099343898945 seconds
# ETA for LogIpOverIu computation in this iteration = 30.70163889458117 seconds
# ETA for LogIpOverIu computation in this iteration = 27.556135641608247 seconds
# ETA for LogIpOverIu computation in this iteration = 24.71155414088019 seconds
# ETA for LogIpOverIu computation in this iteration = 22.444511503722538 seconds
# ETA for LogIpOverIu computation in this iteration = 20.10119735318632 seconds
# ETA for LogIpOverIu computation in this iteration = 17.75893824052737 seconds
# ETA for LogIpOverIu computation in this iteration = 15.496893210780053 seconds
# ETA for LogIpOverIu computation in this iteration = 13.331192785029788 seconds
# ETA for LogIpOverIu computation in this iteration = 10.604806789780726 seconds
# ETA for LogIpOverIu computation in this iteration = 8.374808613266218 seconds
# ETA for LogIpOverIu computation in this iteration = 6.2538777056164765 seconds
# ETA for LogIpOverIu computation in this iteration = 3.709691752926973 seconds
# ETA for LogIpOverIu computation in this iteration = 1.4101299533137568 seconds
# Total time for LogIpOverIu computation in this iteration = 90.55221581459045
# Iteration number 8 has began...
# ETA for LogIpOverIu computation in this iteration = 251.41907215118408 seconds
# ETA for LogIpOverIu computation in this iteration = 100.62421439375196 seconds
# ETA for LogIpOverIu computation in this iteration = 100.41501882029515 seconds
# ETA for LogIpOverIu computation in this iteration = 100.88680986778157 seconds
# ETA for LogIpOverIu computation in this iteration = 95.68323184534447 seconds
# ETA for LogIpOverIu computation in this iteration = 111.4372547964255 seconds
# ETA for LogIpOverIu computation in this iteration = 110.06815654247791 seconds
# ETA for LogIpOverIu computation in this iteration = 102.98501475173306 seconds
# ETA for LogIpOverIu computation in this iteration = 108.9623851776123 seconds
# ETA for LogIpOverIu computation in this iteration = 97.64854455444048 seconds
# ETA for LogIpOverIu computation in this iteration = 91.62976382641082 seconds
# ETA for LogIpOverIu computation in this iteration = 84.7567933723908 seconds
# ETA for LogIpOverIu computation in this iteration = 82.56712790655496 seconds
# ETA for LogIpOverIu computation in this iteration = 76.14487149919334 seconds
# ETA for LogIpOverIu computation in this iteration = 76.35982106730843 seconds
# ETA for LogIpOverIu computation in this iteration = 71.67239471503666 seconds
# ETA for LogIpOverIu computation in this iteration = 68.28033633398307 seconds
# ETA for LogIpOverIu computation in this iteration = 68.48828765780034 seconds
# ETA for LogIpOverIu computation in this iteration = 63.80657409654312 seconds
# ETA for LogIpOverIu computation in this iteration = 57.78439284287966 seconds
# ETA for LogIpOverIu computation in this iteration = 53.563913509409915 seconds
# ETA for LogIpOverIu computation in this iteration = 49.065508063210814 seconds
# ETA for LogIpOverIu computation in this iteration = 44.95145884978561 seconds
# ETA for LogIpOverIu computation in this iteration = 43.18530999051497 seconds
# ETA for LogIpOverIu computation in this iteration = 43.2100722605707 seconds
# ETA for LogIpOverIu computation in this iteration = 40.22616186018648 seconds
# ETA for LogIpOverIu computation in this iteration = 36.7803532045279 seconds
# ETA for LogIpOverIu computation in this iteration = 35.08329400734399 seconds
# ETA for LogIpOverIu computation in this iteration = 32.20972780013121 seconds
# ETA for LogIpOverIu computation in this iteration = 29.14274615084841 seconds
# ETA for LogIpOverIu computation in this iteration = 25.437823786152354 seconds
# ETA for LogIpOverIu computation in this iteration = 22.313705999539092 seconds
# ETA for LogIpOverIu computation in this iteration = 19.319105002883315 seconds
# ETA for LogIpOverIu computation in this iteration = 16.998358557049517 seconds
# ETA for LogIpOverIu computation in this iteration = 14.151372780490862 seconds
# ETA for LogIpOverIu computation in this iteration = 11.294855350329552 seconds
# ETA for LogIpOverIu computation in this iteration = 8.651059859368551 seconds
# ETA for LogIpOverIu computation in this iteration = 5.923141465287342 seconds
# ETA for LogIpOverIu computation in this iteration = 3.132499219614491 seconds
# ETA for LogIpOverIu computation in this iteration = 0.35996773977766017 seconds
# Total time for LogIpOverIu computation in this iteration = 108.24468421936035
# Iteration number 9 has began...
# ETA for LogIpOverIu computation in this iteration = 6.36141300201416 seconds
# ETA for LogIpOverIu computation in this iteration = 107.84043969426837 seconds
# ETA for LogIpOverIu computation in this iteration = 91.69913069407146 seconds
# ETA for LogIpOverIu computation in this iteration = 63.38308094965445 seconds
# ETA for LogIpOverIu computation in this iteration = 48.46763841393068 seconds
# ETA for LogIpOverIu computation in this iteration = 50.7624321381251 seconds
# ETA for LogIpOverIu computation in this iteration = 50.12482892549955 seconds
# ETA for LogIpOverIu computation in this iteration = 46.096080479851686 seconds
# ETA for LogIpOverIu computation in this iteration = 39.86487970907221 seconds
# ETA for LogIpOverIu computation in this iteration = 40.68938136888 seconds
# ETA for LogIpOverIu computation in this iteration = 41.257023304066756 seconds
# ETA for LogIpOverIu computation in this iteration = 36.76472078922183 seconds
# ETA for LogIpOverIu computation in this iteration = 32.92733131015004 seconds
# ETA for LogIpOverIu computation in this iteration = 29.642678032580175 seconds
# ETA for LogIpOverIu computation in this iteration = 26.807773135124 seconds
# ETA for LogIpOverIu computation in this iteration = 24.295959857531955 seconds
# ETA for LogIpOverIu computation in this iteration = 24.860955504246117 seconds
# ETA for LogIpOverIu computation in this iteration = 24.83475519551171 seconds
# ETA for LogIpOverIu computation in this iteration = 22.645049623202596 seconds
# ETA for LogIpOverIu computation in this iteration = 20.666403669577377 seconds
# ETA for LogIpOverIu computation in this iteration = 21.329653642510856 seconds
# ETA for LogIpOverIu computation in this iteration = 19.475151274047914 seconds
# ETA for LogIpOverIu computation in this iteration = 20.051700450202958 seconds
# ETA for LogIpOverIu computation in this iteration = 18.252089411578375 seconds
# ETA for LogIpOverIu computation in this iteration = 16.591392668616194 seconds
# ETA for LogIpOverIu computation in this iteration = 16.357729395915722 seconds
# ETA for LogIpOverIu computation in this iteration = 15.940050033392202 seconds
# ETA for LogIpOverIu computation in this iteration = 14.352118113932137 seconds
# ETA for LogIpOverIu computation in this iteration = 16.74416896852396 seconds
# ETA for LogIpOverIu computation in this iteration = 14.932847986263889 seconds
# ETA for LogIpOverIu computation in this iteration = 13.227869129867004 seconds
# ETA for LogIpOverIu computation in this iteration = 11.624141771813289 seconds
# ETA for LogIpOverIu computation in this iteration = 10.33548549569731 seconds
# ETA for LogIpOverIu computation in this iteration = 8.866193801632726 seconds
# ETA for LogIpOverIu computation in this iteration = 7.476079090123255 seconds
# ETA for LogIpOverIu computation in this iteration = 6.3016739892370905 seconds
# ETA for LogIpOverIu computation in this iteration = 5.0190736128359426 seconds
# ETA for LogIpOverIu computation in this iteration = 3.9338411137322398 seconds
# ETA for LogIpOverIu computation in this iteration = 2.7257552553769266 seconds
# ETA for LogIpOverIu computation in this iteration = 1.6126168152181113 seconds
# ETA for LogIpOverIu computation in this iteration = 0.47797911875956767 seconds
# Total time for LogIpOverIu computation in this iteration = 45.042914628982544
# Iteration number 10 has began...
# ETA for LogIpOverIu computation in this iteration = 4.708953380584717 seconds
# ETA for LogIpOverIu computation in this iteration = 4.564111607415335 seconds
# ETA for LogIpOverIu computation in this iteration = 5.040373802185059 seconds
# ETA for LogIpOverIu computation in this iteration = 5.224471121220975 seconds
# ETA for LogIpOverIu computation in this iteration = 5.3103513521017485 seconds
# ETA for LogIpOverIu computation in this iteration = 5.219009439150493 seconds
# ETA for LogIpOverIu computation in this iteration = 5.082894692054162 seconds
# ETA for LogIpOverIu computation in this iteration = 4.9476474566632005 seconds
# ETA for LogIpOverIu computation in this iteration = 4.7598031134832475 seconds
# ETA for LogIpOverIu computation in this iteration = 4.5857087272518084 seconds
# ETA for LogIpOverIu computation in this iteration = 4.423410334485642 seconds
# ETA for LogIpOverIu computation in this iteration = 4.335304494976073 seconds
# ETA for LogIpOverIu computation in this iteration = 4.219250378659612 seconds
# ETA for LogIpOverIu computation in this iteration = 4.083058119604462 seconds
# ETA for LogIpOverIu computation in this iteration = 3.9655347118319355 seconds
# ETA for LogIpOverIu computation in this iteration = 3.883200318472726 seconds
# ETA for LogIpOverIu computation in this iteration = 3.7538353968561493 seconds
# ETA for LogIpOverIu computation in this iteration = 3.6111411915885077 seconds
# ETA for LogIpOverIu computation in this iteration = 3.437702718384226 seconds
# ETA for LogIpOverIu computation in this iteration = 3.298932671546936 seconds
# ETA for LogIpOverIu computation in this iteration = 3.1162678400675454 seconds
# ETA for LogIpOverIu computation in this iteration = 2.9626539139474026 seconds
# ETA for LogIpOverIu computation in this iteration = 2.807222149843339 seconds
# ETA for LogIpOverIu computation in this iteration = 2.63777829823869 seconds
# ETA for LogIpOverIu computation in this iteration = 2.4958998527732317 seconds
# ETA for LogIpOverIu computation in this iteration = 2.3664427440741966 seconds
# ETA for LogIpOverIu computation in this iteration = 2.203535828028943 seconds
# ETA for LogIpOverIu computation in this iteration = 2.047509683968541 seconds
# ETA for LogIpOverIu computation in this iteration = 1.8998566886125985 seconds
# ETA for LogIpOverIu computation in this iteration = 1.751036057160014 seconds
# ETA for LogIpOverIu computation in this iteration = 1.5871726934858363 seconds
# ETA for LogIpOverIu computation in this iteration = 1.428685440990586 seconds
# ETA for LogIpOverIu computation in this iteration = 1.270336080337504 seconds
# ETA for LogIpOverIu computation in this iteration = 1.121212569206797 seconds
# ETA for LogIpOverIu computation in this iteration = 0.9658314572810521 seconds
# ETA for LogIpOverIu computation in this iteration = 0.8125503490000595 seconds
# ETA for LogIpOverIu computation in this iteration = 0.6636834631160814 seconds
# ETA for LogIpOverIu computation in this iteration = 0.5159646333935105 seconds
# ETA for LogIpOverIu computation in this iteration = 0.36584646465835313 seconds
# ETA for LogIpOverIu computation in this iteration = 0.21609722404945186 seconds
# ETA for LogIpOverIu computation in this iteration = 0.06535179292833483 seconds
# Total time for LogIpOverIu computation in this iteration = 6.106049537658691

# %%
playsound(444,404)

# %%
df
# Out:
#             a         b  LogIpOverIu
# 0    1.290274 -0.625616     0.089335
# 1    1.086438 -0.438219     0.049892
# 2    2.768082 -1.234658     0.719281
# 3    1.086438 -0.344521     0.031833
# 4    0.169178  0.592466     0.279898
# ..        ...       ...          ...
# 930  2.615205 -0.766164    -0.554447
# 931  0.423973  0.170822     0.085045
# 932  1.850822 -0.813014     0.119315
# 933  1.697945 -0.578767    -0.085088
# 934  0.525890  0.451918    -0.030920
#
# [935 rows x 3 columns]

# %%
    plt.scatter(df["a"], df["b"], s=1)
    plt.ylabel('b')
    plt.xlabel('a')
    plt.show()

# %%
if False: # clreate regression model 
    from sklearn.gaussian_process import GaussianProcessRegressor
    from sklearn.gaussian_process.kernels import RBF
    
    X = np.array(df[["a", "b"]])
    Y = np.array(df["LogIpOverIu"])
    #Y = Y.reshape(-1, 1)
    
    
    
    kernel = 1 * RBF(length_scale=1.0, length_scale_bounds=(0.02, 0.25))
    gaussian_process = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=9)
    gaussian_process.fit(X, Y)
    print(gaussian_process.kernel_)
    print(np.sum(np.abs(Y - gaussian_process.predict(X))))

# %%
#fileObj = open('GaussianForPoland.pkl', 'wb')
#pickle.dump(gaussian_process,fileObj)
#fileObj.close()

# %%
zeta = initialize_cities_array()
LogCitySize = np.log(zeta[:,0])

# %%
plt.bar(LogCitySize, zeta[:,1])
# Out:
# <BarContainer object of 4 artists>

# %%
    plt.scatter(DF_boundary["a"][Signs_boundary > 0], DF_boundary["b"][Signs_boundary > 0], c = "red", s=1)
    plt.scatter(DF_boundary["a"][Signs_boundary < 0], DF_boundary["b"][Signs_boundary < 0], c = "blue", s=1)
    plt.ylabel('b')
    plt.xlabel('a')
    plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 21))
ax1.set_box_aspect(1)
ax2.set_box_aspect(1)

plt.subplots_adjust(wspace=0.5)

ax1.bar(LogCitySize, zeta[:,1])
ax2.scatter(DF_boundary["a"][Signs_boundary > 0], DF_boundary["b"][Signs_boundary > 0], c = "red", s=1)
ax2.scatter(DF_boundary["a"][Signs_boundary < 0], DF_boundary["b"][Signs_boundary < 0], c = "blue", s=1)
ax1.set(title= "Beta", xlabel="Log City Size")
ax2.set(title= "Boundary Ip = Iu with Q/maxQ = " + f'{Q_value/maxQ_value():.3f}' + " and Q = " + str(Q_value)
        ,xlabel="a", ylabel="b")

plt.savefig('Boundary' + str(int(time.time()//1)) + '.png', bbox_inches='tight')

plt.show()
